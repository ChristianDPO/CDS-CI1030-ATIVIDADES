# %% [markdown]
# ### Dataset Describe

# %% [markdown]
# - Set to `true` if runnig in Colab

# %%
RUNNING_IN_COLAB = False

# %% [markdown]
# ### Import google drive

# %%
if RUNNING_IN_COLAB:

    from google.colab import drive

    #Mount drive
    drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# ### Import modules

# %%
import pandas

# %% [markdown]
# ### Reading dataset CSV

# %%
if RUNNING_IN_COLAB:
    CSV_PATH = '/content/drive/My Drive/Colab Notebooks/DataScience/All.csv'
else:   
    CSV_PATH = '../../dataset/FinalDataset/All.csv'

CLASS_LABEL_COLUMN = 'class'

# Reads CSV file with data
df = pandas.read_csv(CSV_PATH)
df.head()
# Out:
#    Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0            0                   4                 5                5.5
# 1            0                   4                 5                5.5
# 2            0                   4                 5                5.5
# 3            0                   4                12                5.5
# 4            0                   4                 6                5.5
#
#    longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                  14         4.400000    4               8            3
# 1                  14         6.000000    4              12            4
# 2                  14         5.800000    4              12            5
# 3                  14         5.500000    4              32           16
# 4                  14         7.333334    4              18           11
#
#    ldl_url  ...  SymbolCount_FileName  SymbolCount_Extension  \
# ...

# %%
df.describe()
# Out:
#         Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# count  36707.000000        36707.000000      36707.000000       36707.000000
# mean      21.908110            2.857439          8.954668           5.401719
# std       94.280669            0.906562          4.278406           1.986858
# min        0.000000            2.000000          0.000000           1.500000
# 25%        0.000000            2.000000          6.000000           4.000000
# 50%        0.000000            3.000000          8.000000           5.000000
# 75%       19.000000            3.000000         11.000000           6.500000
# max     1385.000000           19.000000         68.000000          29.500000
#
#        longdomaintokenlen  avgpathtokenlen           tld  charcompvowels  \
# count        36707.000000     36427.000000  36707.000000    36707.000000
# mean             9.746016         4.556261      2.857439       14.976517
# ...

# %% [markdown]
# ### Reading dataset CSV (Infogain)

# %%
if RUNNING_IN_COLAB:
    CSV_PATH = '/content/drive/My Drive/Colab Notebooks/DataScience/All_Infogain.csv'
else:   
    CSV_PATH = '../../dataset/FinalDataset/All_Infogain.csv'

CLASS_LABEL_COLUMN = 'class'

# Reads CSV file with data
df_infogain = pandas.read_csv(CSV_PATH)
df_infogain.head()
# Out:
#    avgpathtokenlen  pathurlRatio  ArgUrlRatio  argDomanRatio  domainUrlRatio  \
# 0            105.0         0.876        0.008          0.087           0.095
# 1             66.0         0.874        0.009          0.091           0.096
# 2             66.0         0.874        0.009          0.091           0.096
# 3             66.0         0.874        0.009          0.091           0.096
# 4             65.0         0.948        0.006          0.182           0.032
#
#    pathDomainRatio  argPathRatio  CharacterContinuityRate  NumberRate_URL  \
# 0            9.174         0.010                    0.435           0.199
# 1            9.136         0.010                    0.682           0.257
# 2            9.136         0.010                    0.682           0.000
# 3            9.136         0.010                    0.682           0.000
# 4           30.000         0.006                    0.727           0.141
#
# ...

# %%
df_infogain.describe()
# Out:
#        avgpathtokenlen  pathurlRatio   ArgUrlRatio  argDomanRatio  \
# count     36417.000000  36417.000000  36417.000000   36417.000000
# mean          4.557593      0.674727      0.237958       2.176043
# std           2.838727      0.150243      0.272202       6.445867
# min           0.667000      0.041000      0.000000       0.000000
# 25%           3.000000      0.604000      0.029000       0.125000
# 50%           4.100000      0.705000      0.050000       0.200000
# 75%           5.000000      0.778000      0.518000       2.667000
# max         105.000000      0.985000      0.975000      92.533000
#
#        domainUrlRatio  pathDomainRatio  argPathRatio  CharacterContinuityRate  \
# count    36417.000000     36417.000000  36417.000000             36417.000000
# mean         0.227918         4.705858      0.326423                 0.624667
# std          0.120900         6.493607      0.338607                 0.160571
# ...
